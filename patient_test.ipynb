# %%
import numpy as np
import pandas as pd

# %%
csv= 'patients.csv'
df=pd.read_csv(csv)
df.head(10)
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
# 5               6                           0                11.64
# 6               7                           1                11.69
# 7               8                           0                12.70
# 8               9                           0                10.88
# 9              10                           1                14.56
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                        100.00   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
# ...

# %%
abnormal=pd.Categorical(df['Genetic_Pedigree_Coefficient'])
abnormal.describe()
# Out:
#             counts   freqs
# categories
#  0.00           17  0.0085
#  0.01           23  0.0115
#  0.02           24  0.0120
#  0.03           17  0.0085
#  0.04           23  0.0115
#  0.05           15  0.0075
#  0.06           25  0.0125
#  0.07           11  0.0055
#  0.08           21  0.0105
#  0.09           21  0.0105
#  0.10           21  0.0105
#  0.11           18  0.0090
#  0.12           23  0.0115
#  0.13           30  0.0150
#  0.14           21  0.0105
#  0.15            9  0.0045
#  0.16           10  0.0050
#  0.17           27  0.0135
#  0.18           19  0.0095
#  0.19           19  0.0095
#  0.20           19  0.0095
#  0.21           18  0.0090
#  0.22           16  0.0080
#  0.23           15  0.0075
#  0.24           19  0.0095
#  0.25           25  0.0125
#  0.26           19  0.0095
#  0.27           14  0.0070
#  0.28           15  0.0075
#  0.29           16  0.0080
# ...            ...     ...
#  0.73           16  0.0080
#  0.74           16  0.0080
# ...

# %%
# df['Genetic_Pedigree_Coefficient']
df_copy= df.copy(deep=True)
df_copy['Genetic_Pedigree_Coefficient'][0]=.19
# Out:
# /home/avanish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.hist(column='Genetic_Pedigree_Coefficient',bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1712b4320>]],
#       dtype=object)

# %%
df.hist(column='Level_of_Hemoglobin',bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa170e344e0>]],
#       dtype=object)

# %%
g=df.groupby('Sex')
g

# %%
g.head()
# Out:
#     Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                1                           1                11.28
# 1                2                           0                 9.75
# 2                3                           1                10.79
# 3                4                           0                11.00
# 4                5                           1                14.17
# 5                6                           0                11.64
# 6                7                           1                11.69
# 7                8                           0                12.70
# 10              11                           1                 8.58
# 15              16                           1                10.96
#
#     Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                           0.19   34   23    1        1.0        0
# 1                           0.23   54   33    1        NaN        0
# ...

# %%
g.
